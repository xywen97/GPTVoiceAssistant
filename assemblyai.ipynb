# %%
import json

import base64
import asyncio
import pyaudio
import websockets

SAMPLE_RATE=16000
FRAMES_PER_BUFFER = 3200
API_KEY = '6c51c72f233f4d3cb4a3897d92021d41'
ASSEMBLYAI_ENDPOINT =  f'wss://api.assemblyai.com/v2/realtime/ws?sample_rate={SAMPLE_RATE}'


p = pyaudio.PyAudio()
audio_stream = p.open(
   frames_per_buffer=FRAMES_PER_BUFFER,
   rate=SAMPLE_RATE,
   format=pyaudio.paInt16,
   channels=1,
   input=True,
)

async def speech_to_text():
    """
    Asynchronous function used to perfrom real-time speech-to-text using AssemblyAI API
    """
    async with websockets.connect(
           ASSEMBLYAI_ENDPOINT,
           ping_interval=5,
           ping_timeout=20,
           extra_headers=(('Authorization', API_KEY), ),
    ) as ws_connection:
        await asyncio.sleep(0.1)
        await ws_connection.recv()
        print('Websocket connection initialised')
        
        async def send_data():
            """
            Asynchronous function used for sending data
            """
            while True:
                try:
                    data = audio_stream.read(FRAMES_PER_BUFFER)
                    data = base64.b64encode(data).decode('utf-8')
                    await ws_connection.send(json.dumps({'audio_data': str(data)}))
                except Exception as e:
                    print(f'Something went wrong. Error code was {e.code}')
                    break
                await asyncio.sleep(0.01)
            return True
       
        async def receive_data():
            """
            Asynchronous function used for receiving data
            """
            while True:
                try:
                    received_msg = await ws_connection.recv()
                    print(json.loads(received_msg)['text'])
                except Exception as e:
                    print(f'Something went wrong. Error code was {e.code}')
                    break
                    
        data_sent, data_received = await asyncio.gather(send_data(), receive_data())


if __name__ == '__main__':

    # asyncio.run(speech_to_text())
    g = speech_to_text()
    await g
# Out:
# Websocket connection initialised
#
#
#
#
#
#
#
# y'all
# y'all chinwa
# y'all chinwa yoham
# y'all chinwa yohamasha
# y'all chinwa yohamasha tum
# y'all chinwa yohamasha tuma
# y'all chinwa yohamasha tuma
# Y'all chinwa, yohamasha, tuma.
#
#
#
#
#
#
#
#
# jud
# judah
# Judah.
#
#
#
#
#
# hello
# hello
# Hello.
#
#
#
#
#
#
# why you
# why you
# Why you.
#
#
#
#
# hello
# hello
# Hello.
# who are
# who are you
# who are you
# Who are you.
#
#
#
#
#
# nihau
# nihau nitra
# nihau nitra sham
# nihau nitra shamadon
# nihau nitra shamadon shim
# nihau nitra shamadon shima
# nihau nitra shamadon shima
# Nihau nitra shamadon shima.
# ---------------------------------------------------------------------------
# CancelledError                            Traceback (most recent call last)
# File c:\Users\xiang\anaconda3\envs\voice\lib\asyncio\tasks.py:605, in sleep(delay, result)
#     604 try:
# --> 605     return await future
#     606 finally:
#
# CancelledError:
#
# During handling of the above exception, another exception occurred:
#
# CancelledError                            Traceback (most recent call last)
# Cell In[2], line 71
#      67 if __name__ == '__main__':
#      68
#      69     # asyncio.run(speech_to_text())
#      70     g = speech_to_text()
# ---> 71     await g
#
# Cell In[2], line 64, in speech_to_text()
#      61             print(f'Something went wrong. Error code was {e.code}')
#      62             break
# ---> 64 data_sent, data_received = await asyncio.gather(send_data(), receive_data())
#
# CancelledError:
